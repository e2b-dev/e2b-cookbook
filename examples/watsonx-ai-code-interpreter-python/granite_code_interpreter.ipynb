# %% [markdown]
# # Code interpreter with IBM WatsonX AI Graphite
#
# This example uses the [E2B SDK](https://github.com/e2b-dev/code-interpreter) as a code interpreter for [IBM Granite Code](https://www.ibm.com/granite/docs/models/code/) on [IBM WatsonX](https://www.ibm.com/watsonx).
#
# The code generated by the LLM runs in a [E2B secure cloud sandbox](https://e2b.dev/docs/sandbox/overview).
# >

# %% [markdown]
# ### 1. Installations
# First, we install IBM WatsonX AI, OpenAI, and the E2B Code Interpreter SDK.

# %%
# Finally install the other packages
# %pip install ibm_watsonx_ai "e2b_code_interpreter==1.0.0" "python-dotenv==1.0.1"
# Out:
# Requirement already satisfied: ibm_watsonx_ai in /opt/homebrew/lib/python3.10/site-packages (1.2.8)
# Requirement already satisfied: e2b_code_interpreter==1.0.0 in /opt/homebrew/lib/python3.10/site-packages (1.0.0)
# Requirement already satisfied: python-dotenv==1.0.1 in /opt/homebrew/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: attrs>=21.3.0 in /opt/homebrew/lib/python3.10/site-packages (from e2b_code_interpreter==1.0.0) (25.1.0)
# Requirement already satisfied: e2b<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from e2b_code_interpreter==1.0.0) (1.1.0)
# Requirement already satisfied: httpx<0.28.0,>=0.20.0 in /opt/homebrew/lib/python3.10/site-packages (from e2b_code_interpreter==1.0.0) (0.27.2)
# Requirement already satisfied: requests in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (2.32.2)
# Requirement already satisfied: urllib3 in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (2.3.0)
# Requirement already satisfied: pandas<2.2.0,>=0.24.2 in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (2.1.4)
# Requirement already satisfied: certifi in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (2025.1.31)
# Requirement already satisfied: lomond in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (0.3.3)
# Requirement already satisfied: tabulate in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (0.9.0)
# Requirement already satisfied: packaging in /Users/james/Library/Python/3.10/lib/python/site-packages (from ibm_watsonx_ai) (24.2)
# Requirement already satisfied: ibm-cos-sdk<2.14.0,>=2.12.0 in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (2.13.6)
# Requirement already satisfied: importlib-metadata in /opt/homebrew/lib/python3.10/site-packages (from ibm_watsonx_ai) (8.6.1)
# Requirement already satisfied: httpcore<2.0.0,>=1.0.5 in /opt/homebrew/lib/python3.10/site-packages (from e2b<2.0.0,>=1.0.0->e2b_code_interpreter==1.0.0) (1.0.7)
# Requirement already satisfied: protobuf<6.0.0,>=3.20.0 in /opt/homebrew/lib/python3.10/site-packages (from e2b<2.0.0,>=1.0.0->e2b_code_interpreter==1.0.0) (5.29.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/james/Library/Python/3.10/lib/python/site-packages (from e2b<2.0.0,>=1.0.0->e2b_code_interpreter==1.0.0) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/james/Library/Python/3.10/lib/python/site-packages (from e2b<2.0.0,>=1.0.0->e2b_code_interpreter==1.0.0) (4.12.2)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.20.0->e2b_code_interpreter==1.0.0) (4.8.0)
# Requirement already satisfied: idna in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.20.0->e2b_code_interpreter==1.0.0) (3.10)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.10/site-packages (from httpx<0.28.0,>=0.20.0->e2b_code_interpreter==1.0.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.10/site-packages (from httpcore<2.0.0,>=1.0.5->e2b<2.0.0,>=1.0.0->e2b_code_interpreter==1.0.0) (0.14.0)
# Requirement already satisfied: ibm-cos-sdk-core==2.13.6 in /opt/homebrew/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai) (2.13.6)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.13.6 in /opt/homebrew/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai) (2.13.6)
# Requirement already satisfied: jmespath<=1.0.1,>=0.10.0 in /opt/homebrew/lib/python3.10/site-packages (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watsonx_ai) (1.0.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/homebrew/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas<2.2.0,>=0.24.2->ibm_watsonx_ai) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests->ibm_watsonx_ai) (3.4.1)
# Requirement already satisfied: zipp>=3.20 in /opt/homebrew/lib/python3.10/site-packages (from importlib-metadata->ibm_watsonx_ai) (3.21.0)
# Requirement already satisfied: six>=1.10.0 in /Users/james/Library/Python/3.10/lib/python/site-packages (from lomond->ibm_watsonx_ai) (1.17.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/james/Library/Python/3.10/lib/python/site-packages (from anyio->httpx<0.28.0,>=0.20.0->e2b_code_interpreter==1.0.0) (1.2.2)
#
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2. Imports and API keys
#
# You need to get your API keys and save them in .env file. You can copy and rename the .env.template file. We import all necessary libraries.
#
# This is what you should put in the .env file:
#
# ```sh
# # Get your credentials at dataplatform.cloud.ibm.com:
# # - Under developer access, select the default project
# # - Get the project ID
# # - Get the wastonxai URL
# # - Create an API key
# WATSONX_PROJECT_ID = "project_id"
# WATSONX_URL = "https://region.ml.cloud.ibm.com"
# WATSONX_API_KEY = "your_api_key"
#
# # Get your API key at e2b.dev:
# E2B_API_KEY = "your_api_key"
# ```

# %%
from ibm_watsonx_ai import APIClient
from ibm_watsonx_ai import Credentials
from ibm_watsonx_ai.foundation_models import ModelInference
import os
import re
from dotenv import load_dotenv
load_dotenv()

WATSONX_PROJECT_ID = os.getenv("WATSONX_PROJECT_ID")
WATSONX_URL = os.getenv("WATSONX_URL")
WATSONX_API_KEY = os.getenv("WATSONX_API_KEY")
E2B_API_KEY = os.getenv("E2B_API_KEY")

# %% [markdown]
# ### 3. Prompts setup
#
# Now we specify a system prompt, assigning a role to LLM. We define a function to extract code blocks formatted in Markdown style from text.

# %%
SYSTEM_PROMPT = """
## your job & context
you are a python data scientist. you are given tasks to complete and you run python code to solve them.
You DO NOT MAKE SYNTAX MISTAKES OR FORGET ANY IMPORTS
- the python code runs in jupyter notebook.
- display visualizations using matplotlib or any other visualization library directly in the notebook. don't worry about saving the visualizations to a file.
- you have access to the internet and can make api requests.
- you also have access to the filesystem and can read/write files.
- you can install any pip package (if it exists) if you need to but the usual packages for data analysis are already preinstalled.
- you can run any python code you want, everything is running in a secure sandbox environment.
"""

credentials = Credentials(
    url = WATSONX_URL,
    api_key = WATSONX_API_KEY,
)

client = APIClient(credentials)

def match_code_blocks(text):
    pattern = re.compile(r'```(?:python)?[\n\r](.*?)```', re.DOTALL)
    return pattern.findall(text)

# %% [markdown]
# ### 4. Defining the function for running the AI-generated code
#
# We define the `code_interpret` function that uses the [E2B SDK](https://e2b.dev/docs) to run AI-generated Python code.
#
# We will use `run_code` to execute the AI-generated code inside the code interpreter sandbox.

# %%
def code_interpret(e2b_code_interpreter, code):
  print("Running code interpreter...")
  exec = e2b_code_interpreter.run_code(
    code,
    # Stream stdout and stderr from the Code Interpreter
    on_stdout=lambda stdout: print("[Code Interpreter]", stdout),
    on_stderr=lambda stderr: print("[Code Interpreter]", stderr),
    # You can also stream code execution results
    # on_result=...
  )

  if exec.error:
    print("[Code Interpreter ERROR]", exec.error)
  else:
    return exec

# %% [markdown]
# ### 5. Getting agent's response
#
# Now we define a ```chat``` function that uses the model to get agent's response to the user's task. If the response contains code, the code interpreter by E2B is used to securely run the code.

# %%
def chat(e2b_code_interpreter, user_message):
    print(f"\n{'='*50}\nUser Message: {user_message}\n{'='*50}")

    model = ModelInference(
        model_id="ibm/granite-34b-code-instruct",
        api_client=client,
        project_id=WATSONX_PROJECT_ID,
        params = { "max_new_tokens": 1024 }
    )

    # The model needs the added line break to behave correctly
    prompt = SYSTEM_PROMPT + user_message + "\n"

    # Extract the assistant's message content
    content = model.generate_text(prompt)

    # Use the assistant's message content for code extraction
    code_results = []
    code_blocks = match_code_blocks(content)
    for code in code_blocks:
        print(f"Code to run: {code}")

        code_interpreter_results = code_interpret(e2b_code_interpreter, code)
        print(f"Code Interpreter Result: {code_interpreter_results}")
        code_results.append(code_interpreter_results)

    return code_results

# %% [markdown]
# ### 6. Printing the output
#
# Finally we get the task result, calling the ```chat``` function.
#
# Read more about how the execution with E2B SDK looks like [here](https://e2b.dev/docs).

# %%
from e2b_code_interpreter import Sandbox

with Sandbox(api_key=E2B_API_KEY) as code_interpreter:
  all_code_blocks_results = chat(
    code_interpreter,
    #"Calculate value of pi using monte carlo method. Use 1000 iterations. Visualize all points of all iterations on a single plot, a point inside the unit circle should be green, other points should be gray.",
    "Plot a 3D chart of sin x cos y please.",
  )

  print(all_code_blocks_results)
  
  if all_code_blocks_results is None:
    print("No output from the code interpreter. Did the LLM generate any code?")
    sys.exit(1)

  for result in all_code_blocks_results:
    # Access stdout
    print("Stdout:", result.logs.stdout)
    # Access stderr
    print("Stderr:", result.logs.stderr)

    # Access any runtime errors
    print("AI-generated Python runtime error:", result.error)

    # Access any results of code execution - charts, interpreter last line, images, etc.
    print("Results:", result.results)
    if len(result.results) == 0:
      sys.exit(0)

result.results[0]
# Out:
# ==================================================
# User Message: Plot a 3D chart of sin x cos y please.
# ==================================================
# Code to run: import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# x = np.linspace(0, 2 * np.pi, 100)
# y = np.linspace(0, 2 * np.pi, 100)
# X, Y = np.meshgrid(x, y)
# Z = np.sin(X) * np.cos(Y)
#
# fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z)
#
# plt.show()
#
# Running code interpreter...
# Code Interpreter Result: Execution(Results: [Result(<Figure size 640x480 with 1 Axes>)], Logs: Logs(stdout: [], stderr: []), Error: None)
# [Execution(Results: [Result(<Figure size 640x480 with 1 Axes>)], Logs: Logs(stdout: [], stderr: []), Error: None)]
# Stdout: []
# Stderr: []
# AI-generated Python runtime error: None
# Results: [Result(<Figure size 640x480 with 1 Axes>)]
# Result(<Figure size 640x480 with 1 Axes>)
